# %% [markdown]
# ### Efficiency Benchmark (LM Studio) — Week 1
#
# Objectif: mesurer **latence**, **throughput (tok/s)** et **RAM système** pour comparer rapidement les modèles que tu charges dans LM Studio.
#
# Pré-requis:
# - LM Studio lancé
# - Serveur API activé (par défaut: `http://localhost:1234`)
# - Un modèle déjà **load** dans LM Studio (le même que tu vas sélectionner ci-dessous)
#
# Ce notebook te laisse:
# - une liste `MODELS` que tu modifies
# - un `model_index` que tu changes selon le modèle chargé
# - un export CSV dans `./results/efficiency_results.csv`

# %%
import pandas as pd

from efficiency_benchmark import (
    DEFAULT_LMSTUDIO_BASE_URL,
    MODELS,
    EfficiencyBenchmark,
    list_lmstudio_models,
)

# %%
# Config LM Studio
BASE_URL = DEFAULT_LMSTUDIO_BASE_URL  # change si besoin
COMPLETIONS_URL = f"{BASE_URL.rstrip('/')}/v1/completions"
MODELS_URL = f"{BASE_URL.rstrip('/')}/v1/models"

# Paramètres benchmark
model_index = 0   # <= change cet index selon le modèle load dans LM Studio
runs = 2
max_tokens = 100
prompt = "What is artificial intelligence? Explain briefly in 1 paragraph."

# %%
# Liste de modèles (tu peux la modifier)
for i, mid in enumerate(MODELS):
    print(f"[{i}] {mid}")

assert 0 <= model_index < len(MODELS), f"model_index invalide: {model_index}"
